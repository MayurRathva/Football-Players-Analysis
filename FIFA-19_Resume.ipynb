# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Imported')
# Out:
# Imported

# %%
print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
data = pd.read_csv(r'E:\FIFA\data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
def country(x):
    return data[data['Nationality'] == x][['Name','Position','Potential','Overall']]

# %%
country('India')
# Out:
#                   Name Position  Potential  Overall
# 8605        S. Chhetri       LS         67       67
# 10011       S. Jhingan      RCB         71       65
# 12598    J. Lalpekhlua       RS         64       63
# 12811  G. Singh Sandhu       GK         68       63
# 13508    A. Edathodika      LCB         62       62
# 14054        P. Halder      RCM         67       61
# 14199         P. Kotal       RB         66       61
# 14218         L. Ralte       LW         62       61
# 14705           N. Das       LB         65       60
# 14786         U. Singh       RM         67       60
# 14915       H. Narzary       LM         66       60
# 15356         R. Singh       ST         59       59
# 15643         S. Singh       CB         65       59
# 15652         A. Thapa      LCM         71       59
# 15855       M. Rafique       CM         61       58
# 15864         A. Singh       GK         62       58
# 15884         B. Singh       ST         58       58
# ...

# %%
def Club(x):
    return data[data['Club'] == x][['Name','Jersey Number','Position','Overall','Nationality','Age','Wage','Value','Contract Valid Until']]

# %%
x = Club('FC Barcelona')
x.head()
# Out:
#                Name  Jersey Number Position  Overall Nationality  Age   Wage  \
# 0          L. Messi           10.0       RF       94   Argentina   31  €565K
# 7         L. Suárez            9.0       RS       91     Uruguay   31  €455K
# 18    M. ter Stegen           22.0       GK       89     Germany   26  €240K
# 20  Sergio Busquets            5.0      CDM       89       Spain   29  €315K
# 32         Coutinho            7.0       LW       88      Brazil   26  €340K
#
#       Value Contract Valid Until
# 0   €110.5M                 2021
# 7      €80M                 2021
# 18     €58M                 2022
# 20   €51.5M                 2023
# 32   €69.5M                 2023

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
#Checking if any data conatins any null value
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
#filling the missing value for proper data visualization
data['ShortPassing'].fillna(data['ShortPassing'].mean(),inplace=True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
#fk accuracy
data['FKAccuracy'].fillna(data['FKAccuracy'].mean(), inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
#Jersey Number
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %%
data.fillna(0,inplace=True)

# %%
def defending(data):
    return int(round(data[['Marking','StandingTackle','SlidingTackle']].mean().mean()))

def general(data):
    return int(round(data[['HeadingAccuracy','Dribbling','Curve','BallControl']].mean().mean()))

def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning', 
                               'Vision','Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 
                               'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 
                               'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 
                               'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy', 
                               'ShotPower','LongShots', 'Penalties']].mean()).mean()))

# %%
#comparison of preferred foot over the different players
plt.figure(figsize=(10,5))
sns.countplot(data['Preferred Foot'],palette='ocean')
plt.title('Most Preferred Foot',fontsize=20)
plt.show()
# Out:
# C:\Users\mayur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Plotting a pie chart to represent share of international reputation
labels=['1','2','3','4','5']
sizes=data['International Reputation'].value_counts()
colors=plt.cm.copper(np.linspace(0,1,5))

plt.rcParams['figure.figsize']=(9,9)
plt.pie(sizes,labels=labels,colors=colors,explode=[0.1,0.2,0.3,0.6,0.9],shadow=True)
plt.legend()
plt.show()

# %%
# plotting a pie chart to represent the share of week foot players

# %%
# different positions acquired by the players
plt.figure(figsize=(25,10))
plt.style.use('fivethirtyeight')
a=sns.countplot(data['Position'],palette='bone')
a.set_xlabel(xlabel='Positions of players',fontsize=20)
a.set_ylabel(ylabel='Count of players',fontsize=20)
plt.show()
# Out:
# C:\Users\mayur\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# defining a function for cleaning the Weight data

def extract_value_from(value):
  out = value.replace('lbs', '')
  return float(out)

# applying the function to weight column
#data['value'] = data['value'].apply(lambda x: extract_value_from(x))
data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

data['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
# defining a function for cleaning the wage column

def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
# applying the function to the wage column

data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))

data['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %%
#comparing the players wages
import warnings
warnings.filterwarnings('ignore')
#plt.rcParams['figure.figsize']=(15,5)
plt.figure(figsize=(15,5))
a=sns.distplot(data['Wage'],color='blue')
a.set_xlabel('Wage Range for Players',fontsize=16)
a.set_ylabel('Count of the Players',fontsize=16)
a.set_title('Distribution of Wages of players',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
p=sns.countplot(data['Skill Moves'],palette='dark')
p.set_title('Count of players on basis of skill moves',fontsize=20)
p.set_xlabel(xlabel='Number of skill moves',fontsize=16)
p.set_ylabel(ylabel='Count of Players',fontsize=16)
plt.show()

# %%
#Height of players
plt.figure(figsize=(10,8))
plt.style.use('fivethirtyeight')
lorder=["5\'1","5\'3","5\'2","5\'4","5\'7","5\'9","6\'2","6\'4","5\'11","5\'8","6\'0","5\'6","5\'10","6\'6","6\'1","6\'3","5\'5","6\'5","6\'7","6\'8","6\'9"]
a=sns.countplot(data['Height'],palette='inferno',order=lorder)
plt.xlabel('Height in Foot per Inch',fontsize=16)
plt.ylabel('Count',fontsize=16)
plt.title('Count of players based on height',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(13,8))
plt.style.use('fivethirtyeight')
sns.distplot(data['Weight'],color='Blue')
plt.title('Different Weights of the Players participating in FIFA-2019',fontsize=20)
plt.xlabel('Weight of Players',fontsize=16)
plt.ylabel('Count of Players',fontsize=16)
plt.show()

# %%
# To show Different Work rate of the players participating in the FIFA 2019

# %%
plt.figure(figsize=(12,8))
plt.style.use('tableau-colorblind10')
a=sns.distplot(data['Special'],bins=58,kde=False,color='b')
a.set_xlabel(xlabel = 'Special score range', fontsize = 16)
a.set_ylabel(ylabel = 'Count of the Players',fontsize = 16)
a.set_title(label = 'Histogram for the Speciality Scores of the Players', fontsize = 20)
plt.show()

# %%
# To show Different potential scores of the players participating in the FIFA 2019

# %%
# To show Different overall scores of the players participating in the FIFA 2019
plt.figure(figsize = (12,8))
plt.style.use('ggplot')
ax = sns.distplot(data['Overall'],bins=52, kde = False, color = 'r')
ax.set_xlabel(xlabel = "Player\'s Scores", fontsize = 16)
ax.set_ylabel(ylabel = 'Number of players', fontsize = 16)
ax.set_title(label = 'Histogram of players Overall Scores', fontsize = 20)
plt.show()

# %%
plt.style.use('dark_background')
data['Nationality'].value_counts().head(50).plot.bar(color='r',figsize=(20,10))
plt.title('Different Countries in FIFA-19')
plt.ylabel('Count')
plt.xlabel('Countries',fontsize=16)
plt.show()

# %%
# selecting some of the interesting and important columns from the set of columns in the given dataset

selected_columns = ['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
                    'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
                    'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
                    'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
                    'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                    'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
                    'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
                    'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
                    'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
                    'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

data_selected=pd.DataFrame(data,columns=selected_columns)

# %%
#plotting a correlation heatmap
plt.figure(figsize=(35,20))
hp=sns.heatmap(data_selected.corr(),annot=True,linewidths=1,linecolor='Blue')
plt.title('HeatMap',fontsize=20)
plt.show()

# %%
#Pandas Series.idxmax() function return the row label of the maximum value. If multiple
#values equal the maximum, the first row label with that value is returned.
x=data.groupby(data['Position'])['Overall'].idxmax()
x
# Out:
# Position
# CAM     17
# CB      12
# CDM     20
# CF     271
# CM      67
# GK       3
# LAM     28
# LB      35
# LCB     24
# LCM     11
# LDM     14
# LF       5
# LM      33
# LS      21
# LW       2
# LWB    474
# RAM    129
# RB      69
# RCB      8
# RCM      4
# RDM     45
# RF       0
# RM      25
# RS       7
# RW      56
# RWB    450
# ST       1
# Name: Overall, dtype: int64

# %%
# best players per each position with their age, club, and nationality based on their overall scores

data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Position', 'Name',
                                                               'Age', 'Club', 'Nationality']].style.background_gradient('Blues')
# Out:
# <style  type="text/css" >
# #T_742811e0_6e2c_11ec_9c83_b068e60b1b45row0_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row4_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row5_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row10_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row11_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row19_col2{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row1_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row18_col2{
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row2_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row12_col2{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row3_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row15_col2,#T_742811e0_6e2c_11ec_9c83_b068e60b1b45row20_col2{
#             background-color:  #89bedc;
# ...

# %%
#Countries with most number of players
data['Nationality'].value_counts().head(10)
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
# Every Nations' Player and their overall scores
plt.rcParams['figure.figsize']=(15,7)
countriesl=['Germany','Spain','England','Brazil','France']
data_countries=data.loc[data['Nationality'].isin(countriesl) & data['Overall']]
a=sns.violinplot(x=data_countries['Nationality'],y=data_countries['Overall'],color='red')
a.set_xlabel(xlabel='Nationality',fontsize=16)
a.set_ylabel(ylabel='Overall',fontsize=16)
a.set_title(label='Violin Plot',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Violin Plot')

# %%
# Every Nations' Player and their wages

plt.rcParams['figure.figsize']=(15,7)
countriesl=['Germany','Spain','England','Brazil','France']
data_countries=data.loc[data['Nationality'].isin(countriesl) & data['Wage']]
a=sns.barplot(x=data_countries['Nationality'],y=data_countries['Overall'],palette='Purples')
a.set_xlabel(xlabel='Nationality',fontsize=16)
a.set_ylabel(ylabel='Wages',fontsize=16)
a.set_title(label='Bar Plot',fontsize=20)
plt.show()

# %%
# Distribution of Wages in some Popular clubs
plt.rcParams['figure.figsize']=(15,7)
clubsl=['Real Madrid','FC Barcelona','Manchester United','Chelsea','Manchester City','Liverpool']
data_clubs = data.loc[data['Club'].isin(clubsl) & data['Wage']]
a=sns.boxplot(x=data_clubs['Club'],y=data_clubs['Wage'],palette='Reds')
a.set_xlabel(xlabel='Clubs',fontsize=16)
a.set_ylabel(ylabel='Wages',fontsize=16)
a.set_title(label='Plot of distribution of wages in different popular clubs',fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
data.sort_values('Age',ascending=False).head(15)[['Name','Age','Club','Nationality']].style.background_gradient('viridis')
# Out:
# <style  type="text/css" >
# #T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row0_col1{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row1_col1,#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row2_col1{
#             background-color:  #7ad151;
#             color:  #000000;
#         }#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row3_col1{
#             background-color:  #2a788e;
#             color:  #000000;
#         }#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row4_col1,#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row5_col1,#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row6_col1,#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row7_col1,#T_8fee62f3_6e2c_11ec_b89c_b068e60b1b45row8_col1{
#             background-color:  #414487;
#             color:  #f1f1f1;
# ...

# %%
#The longest membership in the club
import datetime

# %%
now=datetime.datetime.now()
data['Join_Year']=data['Joined'].dropna().map(lambda x:x.split(',')[1].split(' ')[1])
data['Years_of_Member']=data['Join_Year'].dropna().map(lambda x:now.year-int(x)).astype('int')
membership=data[['Name','Age','Years_of_Member']].sort_values(by='Years_of_Member',ascending=False).head(10)
membership.set_index('Name',inplace=True)
membership
# Out:
#                 Age  Years_of_Member
# Name
# O. Pérez         45               31
# M. Al Shalhoub   37               24
# H. Sogahata      38               24
# M. Ogasawara     39               24
# S. Narazaki      42               23
# M. Wölfli        35               22
# K. Kitamoto      36               22
# C. Källqvist     34               21
# Y. Endo          38               21
# S. Pellissier    39               20

# %%
#top ten left footed footballers
data[data['Preferred Foot']=='Left'][['Name','Age','Club','Nationality']].head(10).style.background_gradient('magma')
# Out:
# <style  type="text/css" >
# #T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row0_col1{
#             background-color:  #fd9668;
#             color:  #000000;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row1_col1{
#             background-color:  #feca8d;
#             color:  #000000;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row2_col1{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row3_col1{
#             background-color:  #721f81;
#             color:  #f1f1f1;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row4_col1,#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row6_col1,#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row7_col1{
#             background-color:  #440f76;
#             color:  #f1f1f1;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row5_col1{
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }#T_b43e0138_6e2c_11ec_8a00_b068e60b1b45row8_col1{
# ...

# %%
#top ten right footed footballers
data[data['Preferred Foot']=='Right'][['Name','Age','Club','Nationality']].head(10).style.background_gradient('copper')
# Out:
# <style  type="text/css" >
# #T_b861265d_6e2c_11ec_950e_b068e60b1b45row0_col1{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_b861265d_6e2c_11ec_950e_b068e60b1b45row1_col1{
#             background-color:  #281910;
#             color:  #f1f1f1;
#         }#T_b861265d_6e2c_11ec_950e_b068e60b1b45row2_col1,#T_b861265d_6e2c_11ec_950e_b068e60b1b45row3_col1,#T_b861265d_6e2c_11ec_950e_b068e60b1b45row4_col1{
#             background-color:  #4f3220;
#             color:  #f1f1f1;
#         }#T_b861265d_6e2c_11ec_950e_b068e60b1b45row5_col1,#T_b861265d_6e2c_11ec_950e_b068e60b1b45row7_col1{
#             background-color:  #ffaf6f;
#             color:  #000000;
#         }#T_b861265d_6e2c_11ec_950e_b068e60b1b45row6_col1{
#             background-color:  #ed9660;
#             color:  #000000;
#         }#T_b861265d_6e2c_11ec_950e_b068e60b1b45row8_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
# comparing the performance of left-footed and right-footed footballers
# ballcontrol vs dribbing
sns.lmplot(x='BallControl',y='Dribbling',data=data,col='Preferred Foot')

# %%
# visualizing clubs with highest number of different countries
x=data.groupby(data['Club'])['Nationality']
x.first()
# Out:
# Club
#  SSV Jahn Regensburg       Germany
# 1. FC Heidenheim 1846      Germany
# 1. FC Kaiserslautern     Lithuania
# 1. FC Köln                 Germany
# 1. FC Magdeburg             France
#                            ...
# Zagłębie Sosnowiec          Poland
# Çaykur Rizespor            Nigeria
# Örebro SK                   Sweden
# Östersunds FK               Sweden
# Śląsk Wrocław               Poland
# Name: Nationality, Length: 652, dtype: object

# %%
y=data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending=False).head(10)

# %%
y1=pd.DataFrame(y)
y1['Nationality']
# Out:
# Club
# No Club                   28
# Brighton & Hove Albion    21
# Fulham                    19
# Udinese                   18
# Napoli                    18
# Empoli                    18
# Eintracht Frankfurt       18
# West Ham United           18
# AS Monaco                 18
# Lazio                     18
# Name: Nationality, dtype: int64

# %%
#create a function to know the details of players

# %%
def playerdata(x):
    return data.loc[x,:]

x = playerdata(0)  #lionel messi, id = 0.
pd.set_option('display.max_rows', 200)
x = pd.DataFrame(x)
print(x)
# Out:
#                                                                        0
# Unnamed: 0                                                             0
# ID                                                                158023
# Name                                                            L. Messi
# Age                                                                   31
# Photo                     https://cdn.sofifa.org/players/4/19/158023.png
# Nationality                                                    Argentina
# Flag                                 https://cdn.sofifa.org/flags/52.png
# Overall                                                               94
# Potential                                                             94
# Club                                                        FC Barcelona
# Club Logo                   https://cdn.sofifa.org/teams/2/light/241.png
# Value                                                          1.105e+08
# ...
